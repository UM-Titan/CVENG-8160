# %% [markdown]
# # This section is on conditions
# ## The next section will be on loops

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if condition:
  'do something here'
else: 
  'do something else'

# %%
x = 5
if x > 3:
  print ('x is greater than 3')
else:
  print ('x is not greater')
# Out:
# x is greater than 3

# %%
x = -1
if x >10:
  print ('greater than 10')
elif x>3 and x<6:
  print ('x is between 3 and 6')
else:
  print ('x is less than 3')
# Out:
# x is less than 3

# %%
roads = ['MO-81','MO-63','i81']
for rd_item in roads:
  if rd_item == 'i81':
    print (rd_item, 'interstate')
  else:
    print (rd_item,'arterial')
# Out:
# MO-81 arterial
# MO-63 arterial
# i81 interstate

# %%
# for loop
list = [1,2,3,4,5,5]
# # list*2 
# list_out = []
# for item in list:
#   # print (item, item*2)
#   list_out.append(item*2)
#   print (list_out)

list_out = [item*2 for item in list]
# out = [cval*2 for cval in list]
# print (out)
print (list_out)
# Out:
# [2, 4, 6, 8, 10, 10]

# %%
list = [1,2,3,4,5,5]
# for cval in list:
#   if cval*5>23:
#     print (cval)

list_out = [ item*4 for item in list if item>3 ]
print (list_out)
# [print (cval) for cval in list if cval*5>23]
# out = [i for i in list if i>3]
# print (out)
# Out:
# [16, 20, 20]

# %% [markdown]
# ### Functions

# %%
y = 2x + 5

# %%
def add_numbers(a,b):
  # do something
  output = a + b

  return output

# %%
add_numbers(2,5)
# Out:
# 7

# %%
# def add(input):
#   do something
#   return something
def filter_list(list):
  out = [i for i in list if i*5>23]
  return out

def filter_list_(list,mu,thresh):
  out = [i for i in list if i*mu>thresh]
  return out

# %%
filter_list_([1,2,3,4,5],2,5)
# Out:
# [3, 4, 5]

# %%
out = filter_list(list)
print (out)
out = filter_list_(list,6,20)
print (out)
# Out:
# [5, 5]
# [4, 5, 5]
