# %% [markdown]
# #Variables

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Think of variables as a container that holds data that can be changed later in the program.

# %%
course_name = "Urban Transportation Data Science"
print(course_name)

# assigning a new value to course name
course_name = "transportation engineering"

print(course_name)
# Out:
# Urban Transportation Data Science
# transportation engineering

# %%
ax = "this is python class" 
print (ax)
# Out:
# this is python class

# %%
## assigning multiple values to multiple variables

a, b, c = 5, 3.2, "Hello"
print (a)
print (b)
print (c)
# Out:
# 5
# 3.2
# Hello

# %% [markdown]
# #Python Data Types

# %% [markdown]
# We can use the type() function to know which class a variable or a value belongs to. Similarly, the isinstance() function is used to check if an object belongs to a particular class.

# %%
a = 5
print(a, "is of type", type(a))

a = 2.0
print(a, "is of type", type(a))

a = 1+2j
# print (a, "is of type", type(1+2j))
print(a, "is complex number?", isinstance(1+2j,complex))
print (isinstance('Python is awesome!',str))
# print (isinstance(2,int))
# Out:
# 5 is of type <class 'int'>
# 2.0 is of type <class 'float'>
# (1+2j) is complex number? True
# True

# %%
print (type([1,2,4]))
print (type({1,2,4}))
print (type({1:'flames',2:'jordan',4:'messi'}))
# Out:
# <class 'list'>
# <class 'set'>
# <class 'dict'>

# %%
# {1:'oranges', 2:'mangoes'}
{1:['oranges'], 2:['mangoes','rice']}
# Out:
# {1: ['oranges'], 2: ['mangoes', 'rice']}

# %% [markdown]
# ## Lists

# %%
## Lists 

a = [5,10,15,20,25,30,35,40]
print (a)

a = [5,10,15,20,25,30,35,40]
# print (a[5])
# # a[2] = 15
# print("a[2] = ", a[2])

# # a[0:3] = [5, 10, 15]
# print("a[0:3] = ", a[1:4])

# a[5:] = [30, 35, 40]
print("a[5:] = ", a[3:])
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40]
# a[5:] =  [20, 25, 30, 35, 40]

# %%
# change values in list
a = [1, 2, 3]
a[2] = 40
print(a)
# Out:
# [1, 2, 40]

# %%
## list of lists
# [[1,2],[3,4]]
ab = [[1,2,3],[4,5,6]]
print (ab)
print (ab[-1])
# Out:
# [[1, 2, 3], [4, 5, 6]]
# [4, 5, 6]

# %% [markdown]
# ## Tuples

# %%
t = (5,'program', 1+3j)

# t[1] = 'program'
print("t[1] = ", t[1])

# t[0:3] = (5, 'program', (1+3j))
print("t[0:3] = ", t[0:3])

# Generates error
# Tuples are immutable
#We can use the slicing operator [] to extract items but we cannot change its value.
# t[0] = 10
# t(0) = 10

## how will you accomplish this??
# Out:
#   File "<ipython-input-33-244615912173>", line 13
#     t(0) = 10
#              ^
# SyntaxError: can't assign to function call

# %% [markdown]
# ## Dictionaries

# %%
#In Python, dictionaries are defined within braces {} 
#with each item being a pair in the form key:value. 
#Key and value can be of any type.

# %%
d.values()
# Out:
# dict_values(['value', 2])

# %%
d = {1:'value','key':2}
type(d)

#We use key to retrieve the respective value. But not the other way around.

print("d[1] = ", d[1]);

print("d['key'] = ", d['key']);

# Generates error
print("d[2] = ", d[2]);
# Out:
# d[1] =  value
# d['key'] =  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-8e5d9ce6c7ab> in <module>()
#       9
#      10 # Generates error
# ---> 11 print("d[2] = ", d[2]);
#
# KeyError: 2

# %% [markdown]
# ##conversion between datatypes

# %%
print (float(5))
print (int(10.6))
float('2.5')
tuple([5,6,7])
dict([[1,2],[3,4]])
# Out:
# 5.0
# 10
# {1: 2, 3: 4}

# %% [markdown]
# ##Output Formatting

# %%
a = 5
print('The value of a is', a)
# Out:
# The value of a is 5

# %%
x = 5; y = 10
print ('The value of x is {} and the value of y is {}'.format(x,y))
# print ('The sum of x and y is {}'.format(x+y))
# Out:
# The value of x is 5 and the value of y is 10

# %%
# using string.format()
x = 5; y = 10
print('The value of x is {} and y is {}'.format(x,y))
## the sum of 5 and 10 is equal to 15
#Here, the curly braces {} are used as placeholders.
# Out:
# The value of x is 5 and y is 10

# %%
## Python inputs
num = input('Enter a number: ')
print ('you entered {} awesome!'.format(num))
# Out:
# Enter a number: 45
# you entered 45 awesome!

# %% [markdown]
# ## Imports

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
from math import pi
print (pi)
# Out:
# 3.141592653589793

# %%
import os
print (os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %% [markdown]
# #Operators

# %%
x = 15
y = 4

# Output: x + y = 19
print('x + y =',x+y)

# Output: x - y = 11
print('x - y =',x-y)

# Output: x * y = 60
print('x * y =',x*y)

# Output: x / y = 3.75
print('x / y =',x/y)

# Output: x // y = 3
print('x // y =',x//y)

# Output: x ** y = 50625
print('x ** y =',x**y)
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x // y = 3
# x ** y = 50625

# %%
2+4
# Out:
# 6

# %%
## comparison

x = 10
y = 12

# Output: x > y is False
print('x > y is',x>y)

# Output: x < y is True
print('x < y is',x<y)

# Output: x == y is False
print('x == y is',x==y)

# Output: x != y is True
print('x != y is',x!=y)

# Output: x >= y is False
print('x >= y is',x>=y)

# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %%
xx = 5
yy =10
print (xx == yy)
print (xx)
# Out:
# False
# 5
