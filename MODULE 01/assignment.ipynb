# %%
# %cd '/content/drive/MyDrive/classes/CVENG_8160/SPRING_2024'
# Out:
# /content/drive/MyDrive/classes/CVENG_8160/SPRING_2024

# %%
# !ls DATA
# Out:
# incidents.csv

# %%
class DataPrep:
  def __init__(self,csv_path):
    self.csv_path = csv_path

  def read_csv(self,**kwargs):
    df = pd.read_csv(self.csv_path,nrows=kwargs['rows'])
    return df

  def filter_csv(self,**kwargs):

    df_filter = df[df['type'] == kwargs['type']]

    return self.df_filter

class Incidents():
  def __init__(self,csv_path):
    self.csv_path = csv_path
    self.columns = ['eventId', 'uuid', 'type', 'main', 'cross','longitude', 'latitude','start', 'estStop', 'clear']

  def format_csv(self):
    if not self.df is None:
      self.df.columns = self.columns

# %%
obj = Incidents('enter path to csv here')

# %%
obj.read_csv(rows=50).format_csv()

# %%
obj.filter_csv(type='Roadwork')
